# %% [markdown]
# # SpaceX Falcon 9 First Stage Landing Prediction

# %% [markdown]
# # 6 - **Launch Sites Locations Analysis with Folium**

# %% [markdown]
# The launch success rate may depend on many factors such as payload mass, orbit type, and so on. It may also depend on the location and proximities of a launch site, i.e., the initial position of rocket trajectories. Finding an optimal location for building a launch site certainly involves many factors and analyzing the existing launch site locations could provide some extra insights.

# %% [markdown]
# ## Objectives

# %% [markdown]
# find some geographical patterns about launch sites:
#
# *   Mark all launch sites on a map
# *   Mark the success/failed launches for each site on the map
# *   Calculate the distances between a launch site to its proximities

# %%
#!pip3 install folium
#!pip3 install wget

# %%
import folium
import wget
import pandas as pd

# %%
# Import folium MarkerCluster plugin
from folium.plugins import MarkerCluster
# Import folium MousePosition plugin
from folium.plugins import MousePosition
# Import folium DivIcon plugin
from folium.features import DivIcon

# %% [markdown]
# ## Mark all launch sites on a map

# %%
# Download and read the 'spacex_launch_geo.csv'
spacex_csv_file = wget.download('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv')
spacex_df=pd.read_csv(spacex_csv_file)

# %%
# Select relevant sub-columns: `Launch Site`, `Lat(Latitude)`, `Long(Longitude)`, `class`
spacex_df = spacex_df[['Launch Site', 'Lat', 'Long', 'class']]
launch_sites_df = spacex_df.groupby(['Launch Site'], as_index=False).first()
launch_sites_df = launch_sites_df[['Launch Site', 'Lat', 'Long']]
launch_sites_df
# Out:
#     Launch Site        Lat        Long
# 0   CCAFS LC-40  28.562302  -80.577356
# 1  CCAFS SLC-40  28.563197  -80.576820
# 2    KSC LC-39A  28.573255  -80.646895
# 3   VAFB SLC-4E  34.632834 -120.610746

# %% [markdown]
# Create a folium Map object, with an initial center location to be NASA Johnson Space Center at Houston, Texas:

# %%
# Start location is NASA Johnson Space Center
nasa_coordinate = [29.559684888503615, -95.0830971930759]
site_map = folium.Map(location=nasa_coordinate, zoom_start=10)

# %% [markdown]
# Using 'folium.Circle' to add a highlighted circle area with a text label on a specific coordinate

# %%
# Create a blue circle at NASA Johnson Space Center's coordinate with a popup label showing its name
circle = folium.Circle(nasa_coordinate, radius=5, color='#2874A6', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
# Create a blue circle at NASA Johnson Space Center's coordinate with a icon showing its name
marker = folium.map.Marker(
    nasa_coordinate,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:blue;"><b>%s</b></div>' % 'NASA JSC'
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# Add a circle for each launch site in data frame 'launch_sites'

# %% [markdown]
# Create and add 'folium.Circle' and 'folium.Marker' for each launch site on the site map

# %%
coord = launch_sites_df[['Lat', 'Long']].values.tolist()
coord
# Out:
# [[28.56230196799018, -80.57735647504778],
#  [28.563197177407144, -80.57682003124195],
#  [28.57325457037815, -80.64689528960382],
#  [34.632834161782775, -120.61074553068327]]

# %%
site_map = folium.Map(location=nasa_coordinate, zoom_start=5)
#circle = folium.Circle(nasa_coordinate, radius=1000, color='#2874A6', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
for point in range(0, len(coord)):
    circle= folium.Circle(coord[point], radius=50, color='#2874A6', fill=True).add_to(site_map)
    marker= folium.Marker(
            location=coord[point],
            popup=launch_sites_df.iloc[point]['Launch Site'], 
            icon=DivIcon(
                    icon_size=(20,20),
                    icon_anchor=(0,0),
                    html=(f"""<div style="font-size: 12; color: blue;">{launch_sites_df.iloc[point]["Launch Site"]}</div>"""))
            ).add_to(site_map)
site_map.add_child(circle)
site_map.add_child(marker)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# # Mark the success/failed launches for each site on the map

# %%
spacex_df.tail(5)
# Out:
#      Launch Site        Lat      Long  class
# 51  CCAFS SLC-40  28.563197 -80.57682      0
# 52  CCAFS SLC-40  28.563197 -80.57682      0
# 53  CCAFS SLC-40  28.563197 -80.57682      0
# 54  CCAFS SLC-40  28.563197 -80.57682      1
# 55  CCAFS SLC-40  28.563197 -80.57682      0

# %% [markdown]
# Create markers for all launch records.
# If a launch was successful (class=1), then use a green marker and if a launch was failed, we use a red marker (class=0)

# %% [markdown]
# Note that a launch only happens in one of the four launch sites, which means many launch records will have the exact same coordinate. Marker clusters can be a good way to simplify a map containing many markers having the same coordinate.

# %% [markdown]
# Create a 'MarkerCluster' object:

# %%
marker_cluster = MarkerCluster()

# %% [markdown]
# Create a new column in 'launch_sites' dataframe called 'marker_color to store the marker colors based on the 'class' value

# %%
# Apply a function to check the value of `class` column
# If class=1, marker_color value will be green
# If class=0, marker_color value will be red

# %%
marker_color=[]
li = spacex_df[['class']].values.tolist()
for i in li:
    if i == 1:
        marker_color.append('#28B463') 
    else:
        marker_color.append('#E74C3C')
spacex_df['marker_color']=marker_color
spacex_df.head()
# Out:
#    Launch Site        Lat       Long  class marker_color
# 0  CCAFS LC-40  28.562302 -80.577356      0      #E74C3C
# 1  CCAFS LC-40  28.562302 -80.577356      0      #E74C3C
# 2  CCAFS LC-40  28.562302 -80.577356      0      #E74C3C
# 3  CCAFS LC-40  28.562302 -80.577356      0      #E74C3C
# 4  CCAFS LC-40  28.562302 -80.577356      0      #E74C3C

# %%
spacex_df.drop(['marker_color'], axis=1)
# Function to assign color to launch outcome
def assign_marker_color(launch_outcome):
    if launch_outcome == 1:
        return 'green'
    else:
        return 'red'
    
spacex_df['marker_color'] = spacex_df['class'].apply(assign_marker_color)
spacex_df.tail(5)
# Out:
#      Launch Site        Lat      Long  class marker_color
# 51  CCAFS SLC-40  28.563197 -80.57682      0          red
# 52  CCAFS SLC-40  28.563197 -80.57682      0          red
# 53  CCAFS SLC-40  28.563197 -80.57682      0          red
# 54  CCAFS SLC-40  28.563197 -80.57682      1        green
# 55  CCAFS SLC-40  28.563197 -80.57682      0          red

# %% [markdown]
# *TODO:* For each launch result in `spacex_df` data frame, add a `folium.Marker` to `marker_cluster`

# %%
# Add the Marker cluster to the site map
site_map.add_child(marker_cluster)
for index, row in spacex_df.iterrows():
    folium.map.Marker(
        (row['Lat'], row['Long']), 
        icon=folium.Icon(color='white',
        icon_color=row['marker_color'])).add_to(marker_cluster)

    site_map.add_child(marker_cluster)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# From the color-labeled markers in marker clusters, one can easily identify which launch sites have relatively high success rates.

# %% [markdown]
# # Calculate the distances between a launch site to its proximities

# %% [markdown]
# Add a MousePosition on the map to get coordinate for a mouse over a point on the map. Thus, I can easily find the coordinates of any points of interests

# %%
# Add Mouse Position to get the coordinate (Lat, Long) for a mouse over on the map
formatter = "function(num) {return L.Util.formatNum(num, 5);};"
mouse_position = MousePosition(
    position='topright',
    separator=' Long: ',
    empty_string='NaN',
    lng_first=False,
    num_digits=20,
    prefix='Lat:',
    lat_formatter=formatter,
    lng_formatter=formatter,
)

site_map.add_child(mouse_position)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# Calculate the distance between two points on the map based on their 'Lat' and 'Long' values using the following method:

# %%
from math import sin, cos, sqrt, atan2, radians

def calculate_distance(lat1, lon1, lat2, lon2):
    # approximate radius of earth in km
    R = 6373.0

    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c
    return distance

# %% [markdown]
# Mark down a point on the closest ocean using MousePosition and calculate the distance between the ocean point to the launch site

# %%
# find coordinate of railway point
# distance_railway = calculate_distance(launch_site_lat, launch_site_lon, raiwaly_lat, raiwaly_lon)
coordinates = [
    [28.56342, -80.57674],
    [28.56342, -80.56756]]
lat1=coordinates[0][0]
lon1=coordinates[0][1]
lat2=coordinates[1][0]
lon2=coordinates[1][1]

distance = calculate_distance(lat1, lon1, lat2, lon2)
distance
# Out:
# 0.8968114005914352

# %% [markdown]
# Create a 'folium.Marker' to show the distance

# %% [markdown]
# Draw a line betwee a launch site to its closest city and coastline

# %%
# Create and add a folium.Marker on your selected closest railway point on the map
#site_map = folium.Map(location=[28.56342, -80.56794], zoom_start=15)
nearest_rail_line = folium.PolyLine(coordinates,weight=1)
site_map.add_child(nearest_rail_line)
distance = calculate_distance(lat1, lon1, lat2, lon2)
circle = folium.Circle([28.56342, -80.56794], radius=100, color='#2874A6', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
distance_marker = folium.Marker(
    [28.56342, -80.56794],
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance)
        )
    )
site_map.add_child(distance_marker)
site_map.add_child(circle)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
#Distance between launch site and Orlando
coordinates2 = [
    [28.56342, -80.57674],
    [28.5349, -81.3784]]
lat1=coordinates2[0][0]
lon1=coordinates2[0][1]
lat2=coordinates2[1][0]
lon2=coordinates2[1][1]

distance2 = calculate_distance(lat1, lon1, lat2, lon2)
distance2

nearest_rail_line2 = folium.PolyLine(coordinates2,weight=3)
site_map.add_child(nearest_rail_line2)
distance2 = calculate_distance(lat1, lon1, lat2, lon2)
circle2 = folium.Circle([28.5349, -81.3784], radius=1100, color='red', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
distance_marker2 = folium.Marker(
    [28.54961, -80.94722],
    icon=DivIcon(
        icon_size=(30,30),
        icon_anchor=(1,1),
        html='<div style="font-size: 30; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance2)
        )
    )
site_map.add_child(distance_marker2)
site_map.add_child(circle2)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
distance2
# Out:
# 78.39034218569917
